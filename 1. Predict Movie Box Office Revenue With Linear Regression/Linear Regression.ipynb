# %% [markdown]
# ### Linear Regression

# %%
import pandas
from pandas import DataFrame
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

# %% [markdown]
# <p>Step 1: Reading the csv file and displaying it.</p>

# %%
data = pandas.read_csv('cost_revenue_clean.csv')

# %%
# Describe will give the summary of our data set
data.describe()
# Out:
#        production_budget_usd  worldwide_gross_usd
# count           5.034000e+03         5.034000e+03
# mean            3.290784e+07         9.515685e+07
# std             4.112589e+07         1.726012e+08
# min             1.100000e+03         2.600000e+01
# 25%             6.000000e+06         7.000000e+06
# 50%             1.900000e+07         3.296202e+07
# 75%             4.200000e+07         1.034471e+08
# max             4.250000e+08         2.783919e+09

# %%
5.03e10
# Out:
# 50300000000.0

# %% [markdown]
# <p> Step 2: Spliting production and revenue budget data into 2 variables. </p>

# %%
X = DataFrame(data, columns=['production_budget_usd']) #production budget
y = DataFrame(data, columns=['worldwide_gross_usd']) #Revenue budget

# %% [markdown]
# <p> Step 3: Create a scatter plot. </p>

# %%
plt.figure(figsize=(10,6))

# To specify the plot name
plt.scatter(X,y, alpha=0.3)

# Adding labels to the plot
plt.title('Film Cost VS Global Revenue')
plt.xlabel('Production Budget $')
plt.ylabel('Worldwide Gross $')

# To fix x and y-axis range(starting,ending)
plt.ylim(0,3000000000)
plt.xlim(0,450000000)

plt.show()

# %% [markdown]
# <p>Step 4: Linear Regression </p>

# %%
# Create an object
regression = LinearRegression()

regression.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# <p>Slope Coefficient: </p>

# %%
regression.coef_  #Theta_1
# Out:
# array([[3.11150918]])

# %%
#Intercept
regression.intercept_

#The intercept here is -ve which shows that the movie with 0 budget can loose $7.3 Billion
#Its also quite un-realistic
# Out:
# array([-7236192.72913963])

# %%
regression.predict(X)
# Out:
# array([[-4.12468355e+06],
#        [-7.20507764e+06],
#        [-5.99158906e+06],
#        ...,
#        [ 9.44885617e+08],
#        [ 6.15065644e+08],
#        [ 1.31515521e+09]])

# %%
plt.figure(figsize=(10,6))

# To specify the plot name
plt.scatter(X,y, alpha=0.3)

#To plot the regression line
plt.plot(X, regression.predict(X), color='red', linewidth=2)  #.predict(x-axis(Normal), y-axis(regression.predict(X)))

# Adding labels to the plot
plt.title('Film Cost VS Global Revenue')
plt.xlabel('Production Budget $')
plt.ylabel('Worldwide Gross $')

# To fix x and y-axis range(starting,ending)
plt.ylim(0,3000000000)
plt.xlim(0,450000000)

plt.show()

# %%
#R^2 or r^2

# amount of variation in film revenue i.e explained by the films budget
# 55% is actually good
regression.score(X, y)
# Out:
# 0.5496485356985727
