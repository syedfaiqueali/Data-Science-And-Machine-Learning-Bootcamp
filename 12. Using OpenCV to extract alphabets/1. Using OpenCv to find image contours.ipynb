# %%
#!pip install opencv-python

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Read image using opencv
img = cv2.imread('Word1.png')

# Display image using matplotlib
plt.imshow(img)
plt.show()
#cv2.destroyAllWindows()

# %%
# convert the image to grayscale format
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.imshow(img_gray)
plt.show()

# %%
# apply binary thresholding
ret, thresh = cv2.threshold(img_gray, 150, 255, cv2.THRESH_BINARY)
cv2.imwrite('image_thres1.jpg', thresh)

plt.imshow(thresh)
plt.show()

# %%
# detect the contours on the binary image using cv2.CHAIN_APPROX_NONE
contours, hierarchy = cv2.findContours(image=thresh, mode=cv2.RETR_TREE, method=cv2.CHAIN_APPROX_NONE)
                                     
# draw contours on the original image
image_copy = img.copy()
cv2.drawContours(image=image_copy, contours=contours, contourIdx=-1, color=(0, 255, 0), thickness=2, lineType=cv2.LINE_AA)
               
plt.imshow(image_copy)
plt.show()

cv2.imwrite('contours_none_image1.jpg', image_copy)
# Out:
# True

# %%
cnt = contours[0]
image_new_copy = img.copy()

x,y,w,h = cv2.boundingRect(cnt)
plt.imshow(cv2.rectangle(image_new_copy, (x,y), (x+w,y+h), (225,0,0), 1))
plt.show()

# %%
cnt = contours[1]
image_new_copy_1 = img.copy()

x,y,w,h = cv2.boundingRect(cnt)
plt.imshow(cv2.rectangle(image_new_copy_1, (x,y), (x+w,y+h), (225,0,0), 1))
plt.show()

# %%
cnt = contours[2]
image_new_copy_2 = img.copy()

x,y,w,h = cv2.boundingRect(cnt)
plt.imshow(cv2.rectangle(image_new_copy_2, (x,y), (x+w,y+h), (225,0,0), 1))
plt.show()

# %%
cnt = contours[3]
image_new_copy_3 = img.copy()

x,y,w,h = cv2.boundingRect(cnt)
plt.imshow(cv2.rectangle(image_new_copy_3, (x,y), (x+w,y+h), (225,0,0), 1))
plt.show()

# %%
cnt = contours[4]
image_new_copy_4 = img.copy()

x,y,w,h = cv2.boundingRect(cnt)
plt.imshow(cv2.rectangle(image_new_copy_4, (x,y), (x+w,y+h), (225,0,0), 1))
plt.show()

# %%
cnt = contours[5]
image_new_copy_5 = img.copy()

x,y,w,h = cv2.boundingRect(cnt)
plt.imshow(cv2.rectangle(image_new_copy_3, (x,y), (x+w,y+h), (225,0,0), 1))
plt.show()
